# %% [markdown]
# <a href="https://colab.research.google.com/github/xersuy/pandas_10min_study/blob/main/pandas_10min_class_17_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 시각화 Plotting 기능 활용하기
# **Pandas로 Series와 DataFrame데이터 시각화 하기**
#
#
# 참고하기 좋음
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#visualization

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame

# %% [markdown]
# ### kind : str
#   df.plot 도움말 참고
#
#
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts.plot()

# %%
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.739035 -0.195841  0.926046 -0.215451
# 2000-01-02  0.671180  1.065816  0.216501  0.758043
# 2000-01-03 -0.844334  1.894383  1.611378 -0.016870
# 2000-01-04 -1.380673 -0.497657  0.207160  0.594930
# 2000-01-05 -0.221180 -0.853813  0.509148  1.146693
# ...              ...       ...       ...       ...
# 2002-09-22  0.723121 -1.065180  0.197199 -1.036356
# 2002-09-23  1.748763 -1.667281  1.309128  1.128757
# 2002-09-24  1.783072 -0.924484  1.335910  2.698305
# 2002-09-25  0.235437 -0.154917 -1.167482 -0.284753
# 2002-09-26  0.502947  0.003295  0.502644  0.881360
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
df = df.cumsum()
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=["B", "C"]).cumsum()
df3.head()
# Out:
#           B         C
# 0 -0.381060  0.281302
# 1 -0.318095  0.391837
# 2  0.287017  0.912604
# 3  0.137834  1.441803
# 4 -0.521834  0.192541

# %%
df3["A"] = pd.Series(list(range(len(df))))
df3.head()
# Out:
#           B         C  A
# 0 -0.381060  0.281302  0
# 1 -0.318095  0.391837  1
# 2  0.287017  0.912604  2
# 3  0.137834  1.441803  3
# 4 -0.521834  0.192541  4

# %%
df3.plot(x="A", y='B')
