# %% [markdown]
# <a href="https://colab.research.google.com/github/xersuy/pandas_10min_study/blob/main/pandas_10min_class_13_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reshaping Data
# **pd.concat([df1, df2])시리즈, 데이터프레임 합치기**

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(['a', 'b'])
s1
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s2 = pd.Series(['c', 'd'])
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %% [markdown]
# pd.concat([s1, s2], ignore_index=True)

# %%
pd.concat([s1, s2], keys=['s1', 's2'],names=['Series name', 'Row ID'])
# Out:
# Series name  Row ID
# s1           0         a
#              1         b
# s2           0         c
#              1         d
# dtype: object

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                    columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
pd.concat([df1, df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df3] )
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1, df3], join='inner')
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
                   columns=['animal', 'name'])
df4
# Out:
#    animal    name
# 0    bird   polly
# 1  monkey  george

# %%
df5 = pd.DataFrame([1], index=['a'])
df5
# Out:
#    0
# a  1

# %%
df6 = pd.DataFrame([2], index=['a'])
df6
# Out:
#    0
# a  2

# %%
# 같은 a 인덱스가 있어서 에러가 나온다.
pd.concat([df5, df6], verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-168ff7322b88> in <module>()
# ----> 1 pd.concat([df5, df6], verify_integrity=True).reset_values()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     452         self.copy = copy
#     453
# --> 454         self.new_axes = self._get_new_axes()
#     455
#     456     def get_result(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
# ...

# %%
pd.concat([df5, df6])
# Out:
#    0
# a  1
# a  2
